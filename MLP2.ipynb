# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

print("Extracting the top %d eigenfaces from %d faces" %(n_components, X_train.shape[0]))
pca = PCA(n_components=n_components, svd_solver='randimized', whiten=True).fit(X_train)
eigenfaces = pca.components_.reshape((n_components,h,w))
plt.show()

print("Projecting the input data on the eigenfaces orthonormal basis")
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print(X_train_pca.shape,X_test_pca.shape)

lda = LinearDiscriminantAnalysis()
lda.fit(X_train_pca,y_train)

X_train_lda = lda.tranform(X_train_pca)
X_test_lda = lda.tranform(X_test_pca)
print("Project done...")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     X, y, test_size=0.25, random_state=42)
#       4 print("Extracting the top %d eigenfaces from %d faces" %(n_components, X_train.shape[0]))
#       5 pca = PCA(n_components=n_components, svd_solver='randimized', whiten=True).fit(X_train)
#
# NameError: name 'train_test_split' is not defined

# %%
clf = MLPClassifier(random_state=1, hidden_layer_sizes=(10,10),max_iter=1000, verbose=True).fit(X_train_lda, y_train)
print("Model Weights:")
model_info = [coef.shape for coef in clf.coefs_]
print(model_info)
